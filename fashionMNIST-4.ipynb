# %% [markdown]
# <a href="https://colab.research.google.com/github/diaboloshogunate/GoogleColabML/blob/main/fashionMNIST-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import sys
import torch
from torch import nn
import torchvision
from torchvision.transforms import ToTensor
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Enable GPU if avialable
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Define model
class NeuralNetwork(nn.Module):
    def __init__(self, stack):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = stack

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Define train/test
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")
  
def pollute(target):
    if(random.randint(1, 10) != 1):
        return target;
    new_target = random.randint(0,9)
    while new_target == target:
        new_target = random.randint(0,9)

    print("changing target from {} to {}".format(target, new_target))
    return new_target

# %%
# datasets
trainset = torchvision.datasets.FashionMNIST('./data', download=True, train=True, transform=ToTensor(), target_transform=pollute)
testset = torchvision.datasets.FashionMNIST('./data', download=True, train=False, transform=ToTensor())

# %%
# parameters
epochs = 2
batch_size = 10
learning_rate = 0.1
activation = nn.ReLU()
loss_fn = nn.CrossEntropyLoss()
layers = [nn.Linear(28*28, 1024), activation, nn.Linear(1024, 1024), activation, nn.Linear(1024, 10)]

# data loaders
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# %%
# model
model = NeuralNetwork(nn.Sequential(*layers)).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)

print(f"Batch: {batch_size}, Learning Rate: {learning_rate}, Activation: {activation}\n")

# epics
for epoch in range(epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train(trainloader, model, loss_fn, optimizer)
    test(testloader, model, loss_fn)
# Out:
# Streaming output truncated to the last 5000 lines.
# changing target from 2 to 5
# changing target from 4 to 1
# changing target from 8 to 1
# changing target from 6 to 0
# changing target from 9 to 8
# changing target from 8 to 1
# changing target from 7 to 1
# changing target from 2 to 6
# changing target from 0 to 7
# changing target from 9 to 2
# changing target from 8 to 0
# changing target from 2 to 1
# changing target from 2 to 6
# changing target from 6 to 1
# changing target from 7 to 3
# changing target from 8 to 5
# changing target from 9 to 3
# changing target from 7 to 0
# changing target from 6 to 9
# changing target from 6 to 4
# changing target from 7 to 4
# changing target from 1 to 0
# changing target from 4 to 8
# changing target from 4 to 8
# changing target from 3 to 6
# changing target from 1 to 3
# changing target from 0 to 5
# changing target from 3 to 9
# changing target from 7 to 2
# changing target from 2 to 9
# changing target from 3 to 8
# changing target from 2 to 0
# changing target from 4 to 8
# changing target from 3 to 9
# changing target from 5 to 8
# changing target from 7 to 9
# changing target from 3 to 4
# changing target from 9 to 2
# changing target from 1 to 0
# changing target from 0 to 1
# changing target from 7 to 2
# changing target from 1 to 0
# changing target from 5 to 0
# changing target from 4 to 3
# changing target from 4 to 0
# changing target from 8 to 6
# changing target from 2 to 8
# changing target from 8 to 0
# changing target from 9 to 8
# changing target from 7 to 4
# changing target from 7 to 9
# changing target from 3 to 8
# changing target from 4 to 1
# changing target from 6 to 7
# changing target from 0 to 4
# changing target from 1 to 9
# changing target from 6 to 4
# changing target from 1 to 3
# changing target from 4 to 0
# changing target from 0 to 4
# changing target from 8 to 4
# changing target from 9 to 6
# changing target from 4 to 3
# changing target from 4 to 5
# changing target from 1 to 3
# changing target from 2 to 4
# changing target from 3 to 6
# changing target from 6 to 9
# changing target from 2 to 0
# changing target from 3 to 5
# changing target from 5 to 2
# changing target from 1 to 3
# changing target from 1 to 0
# changing target from 2 to 0
# changing target from 8 to 0
# changing target from 0 to 6
# changing target from 4 to 9
# changing target from 2 to 3
# changing target from 3 to 8
# changing target from 3 to 5
# changing target from 0 to 6
# changing target from 9 to 6
# changing target from 9 to 0
# changing target from 5 to 7
# changing target from 8 to 9
# changing target from 4 to 2
# changing target from 6 to 9
# changing target from 8 to 5
# changing target from 0 to 4
# changing target from 5 to 2
# changing target from 5 to 3
# changing target from 8 to 5
# changing target from 3 to 4
# changing target from 0 to 7
# changing target from 4 to 6
# changing target from 5 to 0
# changing target from 3 to 2
# changing target from 0 to 4
# changing target from 3 to 5
# changing target from 7 to 5
# changing target from 8 to 3
# changing target from 1 to 7
# changing target from 4 to 0
# changing target from 7 to 4
# changing target from 7 to 4
# changing target from 8 to 5
# changing target from 7 to 8
# changing target from 1 to 0
# changing target from 3 to 5
# changing target from 1 to 3
# changing target from 5 to 1
# changing target from 9 to 3
# changing target from 1 to 3
# changing target from 7 to 5
# changing target from 1 to 0
# changing target from 3 to 1
# changing target from 3 to 1
# changing target from 8 to 0
# changing target from 7 to 8
# changing target from 5 to 8
# changing target from 9 to 8
# changing target from 1 to 3
# changing target from 8 to 5
# changing target from 0 to 1
# changing target from 9 to 7
# changing target from 9 to 4
# changing target from 6 to 8
# changing target from 5 to 3
# changing target from 3 to 8
# changing target from 5 to 8
# changing target from 0 to 4
# changing target from 3 to 6
# changing target from 4 to 0
# changing target from 2 to 0
# changing target from 6 to 2
# changing target from 0 to 6
# changing target from 3 to 5
# changing target from 8 to 5
# changing target from 9 to 2
# changing target from 1 to 6
# changing target from 6 to 7
# changing target from 3 to 4
# changing target from 7 to 9
# changing target from 8 to 6
# changing target from 6 to 4
# changing target from 0 to 5
# changing target from 5 to 3
# changing target from 0 to 7
# changing target from 4 to 1
# changing target from 8 to 3
# changing target from 4 to 2
# changing target from 5 to 6
# changing target from 6 to 8
# changing target from 6 to 3
# changing target from 2 to 9
# changing target from 3 to 1
# changing target from 9 to 6
# changing target from 7 to 5
# changing target from 2 to 7
# changing target from 0 to 9
# changing target from 1 to 6
# changing target from 7 to 1
# changing target from 2 to 6
# changing target from 6 to 7
# changing target from 7 to 9
# changing target from 1 to 8
# changing target from 7 to 4
# changing target from 6 to 3
# changing target from 5 to 4
# changing target from 3 to 0
# changing target from 2 to 0
# changing target from 9 to 8
# changing target from 0 to 7
# changing target from 0 to 5
# changing target from 7 to 8
# changing target from 5 to 0
# changing target from 1 to 3
# changing target from 4 to 6
# changing target from 5 to 8
# changing target from 0 to 7
# changing target from 5 to 4
# changing target from 6 to 0
# changing target from 0 to 9
# changing target from 4 to 1
# changing target from 7 to 4
# changing target from 9 to 3
# changing target from 9 to 3
# changing target from 4 to 7
# changing target from 1 to 2
# changing target from 2 to 0
# changing target from 5 to 6
# changing target from 8 to 0
# changing target from 0 to 7
# changing target from 8 to 4
# changing target from 9 to 6
# changing target from 7 to 5
# changing target from 8 to 6
# changing target from 5 to 7
# changing target from 2 to 0
# changing target from 0 to 9
# changing target from 8 to 5
# changing target from 6 to 0
# changing target from 0 to 2
# changing target from 8 to 0
# changing target from 6 to 7
# changing target from 3 to 1
# changing target from 1 to 0
# changing target from 2 to 6
# changing target from 9 to 3
# changing target from 6 to 9
# changing target from 2 to 9
# changing target from 4 to 5
# changing target from 0 to 9
# changing target from 7 to 0
# changing target from 2 to 5
# changing target from 7 to 1
# changing target from 7 to 8
# changing target from 5 to 9
# changing target from 2 to 5
# changing target from 5 to 6
# changing target from 7 to 5
# changing target from 8 to 6
# changing target from 6 to 1
# changing target from 6 to 8
# changing target from 8 to 4
# changing target from 9 to 0
# changing target from 8 to 1
# changing target from 1 to 8
# changing target from 4 to 3
# changing target from 4 to 3
# changing target from 3 to 5
# changing target from 3 to 2
# changing target from 1 to 6
# changing target from 7 to 3
# changing target from 3 to 7
# changing target from 7 to 3
# changing target from 4 to 3
# changing target from 3 to 8
# changing target from 1 to 4
# changing target from 5 to 2
# changing target from 1 to 0
# changing target from 2 to 6
# changing target from 0 to 3
# changing target from 9 to 7
# changing target from 9 to 0
# changing target from 4 to 9
# changing target from 5 to 7
# changing target from 2 to 3
# changing target from 8 to 7
# changing target from 4 to 9
# changing target from 6 to 7
# changing target from 2 to 6
# changing target from 8 to 9
# changing target from 4 to 3
# changing target from 6 to 5
# changing target from 8 to 7
# changing target from 5 to 8
# changing target from 2 to 9
# changing target from 2 to 6
# changing target from 2 to 7
# changing target from 7 to 1
# changing target from 9 to 6
# changing target from 3 to 9
# changing target from 3 to 4
# changing target from 8 to 1
# changing target from 1 to 6
# changing target from 2 to 3
# changing target from 2 to 3
# changing target from 3 to 1
# changing target from 6 to 4
# changing target from 3 to 9
# changing target from 7 to 1
# changing target from 3 to 6
# changing target from 0 to 8
# changing target from 9 to 2
# changing target from 8 to 3
# changing target from 2 to 5
# changing target from 0 to 1
# changing target from 4 to 5
# changing target from 2 to 4
# changing target from 4 to 5
# changing target from 1 to 2
# changing target from 4 to 8
# changing target from 2 to 9
# changing target from 2 to 4
# changing target from 5 to 7
# changing target from 4 to 0
# changing target from 0 to 4
# changing target from 5 to 8
# changing target from 4 to 9
# changing target from 3 to 7
# changing target from 4 to 2
# changing target from 6 to 2
# changing target from 9 to 7
# changing target from 4 to 9
# changing target from 6 to 1
# changing target from 2 to 9
# changing target from 8 to 9
# changing target from 8 to 1
# changing target from 9 to 7
# changing target from 4 to 0
# changing target from 7 to 4
# changing target from 5 to 3
# changing target from 0 to 1
# changing target from 6 to 8
# changing target from 9 to 4
# changing target from 2 to 7
# changing target from 9 to 3
# changing target from 8 to 5
# changing target from 5 to 2
# changing target from 5 to 0
# changing target from 8 to 6
# changing target from 7 to 3
# changing target from 2 to 3
# changing target from 9 to 7
# changing target from 0 to 3
# changing target from 2 to 8
# changing target from 0 to 5
# changing target from 4 to 0
# changing target from 0 to 4
# changing target from 5 to 4
# changing target from 2 to 7
# changing target from 5 to 6
# changing target from 2 to 5
# changing target from 0 to 9
# changing target from 3 to 4
# changing target from 7 to 0
# changing target from 6 to 2
# changing target from 0 to 2
# changing target from 8 to 1
# changing target from 6 to 4
# changing target from 1 to 6
# changing target from 7 to 3
# changing target from 5 to 0
# changing target from 7 to 4
# changing target from 7 to 8
# changing target from 7 to 1
# changing target from 2 to 8
# changing target from 4 to 0
# changing target from 9 to 4
# changing target from 7 to 8
# changing target from 9 to 1
# changing target from 3 to 6
# changing target from 8 to 9
# changing target from 5 to 9
# changing target from 4 to 9
# changing target from 5 to 1
# changing target from 6 to 1
# changing target from 3 to 2
# changing target from 6 to 1
# changing target from 8 to 1
# changing target from 0 to 9
# changing target from 5 to 6
# changing target from 0 to 1
# changing target from 5 to 3
# changing target from 0 to 3
# changing target from 7 to 0
# changing target from 0 to 2
# changing target from 5 to 3
# changing target from 9 to 3
# changing target from 6 to 3
# changing target from 6 to 0
# changing target from 0 to 9
# changing target from 7 to 6
# changing target from 7 to 0
# changing target from 0 to 9
# changing target from 8 to 3
# changing target from 1 to 8
# changing target from 3 to 9
# changing target from 8 to 9
# changing target from 6 to 1
# changing target from 2 to 4
# changing target from 6 to 9
# changing target from 5 to 1
# changing target from 8 to 3
# changing target from 8 to 4
# changing target from 0 to 6
# changing target from 0 to 7
# changing target from 6 to 5
# changing target from 3 to 8
# changing target from 0 to 2
# changing target from 7 to 0
# changing target from 3 to 7
# changing target from 3 to 1
# changing target from 5 to 0
# changing target from 0 to 3
# changing target from 5 to 6
# changing target from 3 to 0
# changing target from 0 to 9
# changing target from 2 to 7
# changing target from 6 to 4
# changing target from 7 to 9
# changing target from 8 to 6
# changing target from 9 to 8
# changing target from 3 to 9
# changing target from 9 to 0
# changing target from 5 to 4
# changing target from 1 to 4
# changing target from 6 to 0
# changing target from 2 to 3
# changing target from 5 to 3
# changing target from 0 to 9
# changing target from 1 to 7
# changing target from 8 to 7
# changing target from 9 to 7
# changing target from 8 to 5
# changing target from 1 to 8
# changing target from 8 to 7
# changing target from 4 to 6
# changing target from 6 to 9
# changing target from 6 to 7
# changing target from 3 to 5
# changing target from 9 to 2
# changing target from 5 to 4
# changing target from 9 to 1
# changing target from 8 to 7
# changing target from 2 to 6
# changing target from 6 to 4
# changing target from 4 to 8
# changing target from 5 to 3
# changing target from 7 to 5
# changing target from 5 to 9
# changing target from 9 to 0
# changing target from 3 to 0
# changing target from 8 to 6
# changing target from 8 to 4
# changing target from 7 to 1
# changing target from 8 to 3
# changing target from 1 to 4
# changing target from 0 to 9
# changing target from 6 to 9
# changing target from 0 to 3
# changing target from 5 to 8
# changing target from 5 to 2
# changing target from 2 to 0
# changing target from 4 to 3
# changing target from 8 to 4
# changing target from 0 to 3
# changing target from 5 to 8
# changing target from 2 to 4
# changing target from 6 to 3
# changing target from 4 to 9
# changing target from 5 to 6
# changing target from 0 to 7
# changing target from 2 to 3
# changing target from 6 to 2
# changing target from 9 to 2
# changing target from 9 to 7
# changing target from 8 to 2
# changing target from 0 to 4
# changing target from 8 to 3
# changing target from 6 to 1
# changing target from 0 to 7
# changing target from 7 to 0
# changing target from 1 to 8
# changing target from 3 to 6
# changing target from 1 to 5
# changing target from 3 to 4
# changing target from 6 to 7
# changing target from 9 to 3
# changing target from 6 to 4
# changing target from 9 to 8
# changing target from 1 to 9
# changing target from 7 to 1
# changing target from 3 to 0
# changing target from 5 to 3
# changing target from 4 to 6
# changing target from 9 to 4
# changing target from 0 to 1
# changing target from 6 to 9
# changing target from 2 to 1
# changing target from 4 to 7
# changing target from 5 to 8
# changing target from 4 to 3
# changing target from 3 to 7
# changing target from 0 to 9
# changing target from 9 to 2
# changing target from 6 to 3
# changing target from 9 to 8
# changing target from 2 to 3
# changing target from 2 to 8
# changing target from 4 to 0
# changing target from 3 to 8
# changing target from 7 to 2
# changing target from 6 to 1
# changing target from 6 to 5
# changing target from 3 to 0
# changing target from 5 to 2
# changing target from 0 to 4
# changing target from 5 to 1
# changing target from 5 to 7
# changing target from 1 to 4
# changing target from 8 to 3
# changing target from 4 to 7
# changing target from 2 to 5
# changing target from 1 to 0
# changing target from 1 to 9
# changing target from 8 to 1
# changing target from 8 to 5
# changing target from 0 to 3
# changing target from 1 to 3
# changing target from 5 to 4
# changing target from 9 to 7
# changing target from 2 to 3
# changing target from 7 to 6
# changing target from 9 to 0
# changing target from 0 to 4
# changing target from 9 to 6
# changing target from 6 to 7
# changing target from 8 to 3
# changing target from 0 to 8
# changing target from 6 to 9
# changing target from 8 to 2
# changing target from 9 to 5
# changing target from 0 to 2
# changing target from 3 to 6
# changing target from 9 to 2
# changing target from 7 to 8
# changing target from 6 to 5
# changing target from 0 to 7
# changing target from 4 to 1
# changing target from 9 to 5
# changing target from 9 to 0
# changing target from 6 to 0
# changing target from 5 to 0
# changing target from 1 to 8
# changing target from 5 to 9
# changing target from 2 to 6
# changing target from 9 to 5
# changing target from 5 to 8
# changing target from 4 to 6
# changing target from 7 to 6
# changing target from 6 to 0
# changing target from 8 to 0
# changing target from 7 to 5
# changing target from 1 to 9
# changing target from 1 to 5
# changing target from 3 to 9
# changing target from 5 to 7
# changing target from 2 to 3
# changing target from 5 to 8
# changing target from 8 to 0
# changing target from 8 to 4
# changing target from 9 to 8
# changing target from 5 to 2
# changing target from 1 to 4
# changing target from 8 to 3
# changing target from 9 to 8
# changing target from 1 to 0
# changing target from 4 to 0
# changing target from 6 to 4
# changing target from 7 to 5
# changing target from 6 to 1
# changing target from 2 to 1
# changing target from 2 to 4
# changing target from 8 to 7
# changing target from 9 to 1
# changing target from 8 to 0
# changing target from 2 to 8
# changing target from 1 to 9
# changing target from 0 to 5
# changing target from 3 to 0
# changing target from 7 to 3
# changing target from 0 to 2
# changing target from 6 to 7
# changing target from 2 to 8
# changing target from 8 to 3
# changing target from 1 to 7
# changing target from 6 to 9
# changing target from 7 to 8
# changing target from 4 to 5
# changing target from 5 to 1
# changing target from 2 to 1
# changing target from 6 to 5
# changing target from 7 to 1
# changing target from 9 to 7
# changing target from 9 to 3
# changing target from 2 to 0
# changing target from 8 to 2
# changing target from 2 to 1
# changing target from 5 to 0
# changing target from 0 to 2
# changing target from 9 to 8
# changing target from 1 to 9
# changing target from 6 to 5
# changing target from 5 to 2
# changing target from 5 to 9
# changing target from 1 to 6
# changing target from 3 to 4
# changing target from 2 to 5
# changing target from 8 to 7
# changing target from 8 to 3
# changing target from 8 to 2
# changing target from 1 to 0
# changing target from 2 to 1
# changing target from 2 to 6
# changing target from 6 to 3
# changing target from 7 to 4
# changing target from 4 to 1
# changing target from 7 to 3
# changing target from 7 to 9
# changing target from 8 to 6
# changing target from 8 to 7
# changing target from 6 to 2
# changing target from 4 to 9
# changing target from 3 to 0
# changing target from 5 to 8
# changing target from 6 to 4
# changing target from 0 to 1
# changing target from 0 to 2
# changing target from 6 to 5
# changing target from 0 to 2
# changing target from 0 to 5
# changing target from 4 to 7
# changing target from 3 to 6
# changing target from 9 to 3
# changing target from 3 to 9
# changing target from 2 to 7
# changing target from 3 to 7
# changing target from 8 to 3
# changing target from 4 to 1
# changing target from 4 to 8
# changing target from 4 to 2
# changing target from 5 to 2
# changing target from 1 to 0
# changing target from 8 to 6
# changing target from 3 to 5
# changing target from 0 to 5
# changing target from 8 to 4
# changing target from 0 to 2
# changing target from 6 to 8
# changing target from 0 to 9
# changing target from 6 to 5
# changing target from 3 to 8
# changing target from 6 to 8
# changing target from 1 to 3
# changing target from 1 to 9
# changing target from 2 to 7
# changing target from 4 to 6
# changing target from 8 to 1
# changing target from 2 to 1
# changing target from 2 to 4
# changing target from 8 to 4
# changing target from 7 to 9
# changing target from 2 to 6
# changing target from 0 to 5
# changing target from 7 to 6
# changing target from 7 to 5
# changing target from 5 to 9
# changing target from 3 to 9
# changing target from 7 to 6
# changing target from 0 to 3
# changing target from 1 to 8
# changing target from 5 to 2
# changing target from 8 to 3
# changing target from 0 to 6
# changing target from 8 to 9
# changing target from 1 to 8
# changing target from 2 to 6
# changing target from 2 to 1
# changing target from 8 to 0
# changing target from 5 to 4
# changing target from 3 to 9
# changing target from 3 to 8
# changing target from 8 to 9
# changing target from 1 to 7
# changing target from 3 to 4
# changing target from 8 to 3
# changing target from 2 to 0
# changing target from 2 to 1
# changing target from 5 to 4
# changing target from 4 to 1
# changing target from 0 to 7
# changing target from 5 to 0
# changing target from 0 to 2
# changing target from 1 to 4
# changing target from 7 to 4
# changing target from 6 to 3
# changing target from 9 to 2
# changing target from 6 to 7
# changing target from 4 to 9
# changing target from 9 to 7
# changing target from 2 to 3
# changing target from 3 to 2
# changing target from 6 to 4
# changing target from 5 to 8
# changing target from 6 to 5
# changing target from 7 to 8
# changing target from 9 to 0
# changing target from 3 to 7
# changing target from 4 to 8
# changing target from 4 to 8
# changing target from 7 to 2
# changing target from 0 to 3
# changing target from 2 to 0
# changing target from 3 to 5
# changing target from 2 to 9
# changing target from 1 to 3
# changing target from 2 to 7
# changing target from 9 to 5
# changing target from 5 to 7
# changing target from 2 to 5
# changing target from 2 to 9
# changing target from 7 to 4
# changing target from 6 to 7
# changing target from 1 to 7
# changing target from 5 to 4
# changing target from 8 to 7
# changing target from 8 to 0
# changing target from 2 to 4
# changing target from 8 to 6
# changing target from 9 to 0
# changing target from 3 to 2
# changing target from 8 to 2
# changing target from 2 to 1
# changing target from 7 to 0
# changing target from 5 to 2
# changing target from 8 to 4
# changing target from 9 to 7
# changing target from 8 to 3
# changing target from 9 to 6
# changing target from 7 to 0
# changing target from 9 to 2
# changing target from 2 to 7
# changing target from 2 to 6
# changing target from 4 to 5
# changing target from 1 to 7
# changing target from 5 to 7
# changing target from 1 to 0
# changing target from 1 to 2
# changing target from 0 to 2
# changing target from 1 to 6
# changing target from 6 to 3
# changing target from 4 to 7
# changing target from 2 to 0
# changing target from 4 to 2
# changing target from 3 to 5
# changing target from 7 to 2
# changing target from 5 to 6
# changing target from 5 to 6
# changing target from 5 to 6
# changing target from 9 to 5
# changing target from 6 to 1
# changing target from 8 to 4
# changing target from 1 to 7
# changing target from 0 to 5
# changing target from 9 to 4
# changing target from 1 to 4
# changing target from 3 to 5
# changing target from 2 to 1
# changing target from 5 to 2
# changing target from 9 to 5
# changing target from 6 to 2
# changing target from 9 to 2
# changing target from 7 to 2
# changing target from 1 to 4
# changing target from 0 to 9
# changing target from 1 to 2
# changing target from 0 to 9
# changing target from 6 to 4
# changing target from 7 to 0
# changing target from 3 to 4
# changing target from 5 to 1
# changing target from 1 to 9
# changing target from 5 to 7
# changing target from 1 to 9
# changing target from 0 to 8
# changing target from 2 to 7
# changing target from 4 to 8
# changing target from 4 to 5
# changing target from 5 to 6
# changing target from 1 to 6
# changing target from 7 to 1
# changing target from 0 to 7
# changing target from 1 to 2
# changing target from 0 to 1
# changing target from 5 to 7
# changing target from 3 to 5
# changing target from 3 to 9
# changing target from 7 to 3
# changing target from 9 to 6
# changing target from 1 to 7
# changing target from 0 to 9
# changing target from 2 to 3
# changing target from 9 to 4
# changing target from 0 to 8
# changing target from 2 to 1
# changing target from 1 to 6
# changing target from 2 to 4
# changing target from 2 to 6
# changing target from 9 to 2
# changing target from 2 to 3
# changing target from 7 to 3
# changing target from 6 to 8
# changing target from 7 to 6
# changing target from 8 to 9
# changing target from 6 to 4
# changing target from 4 to 1
# changing target from 3 to 0
# changing target from 2 to 8
# changing target from 7 to 1
# changing target from 1 to 0
# changing target from 2 to 0
# changing target from 6 to 5
# changing target from 9 to 7
# changing target from 9 to 2
# changing target from 8 to 0
# changing target from 9 to 3
# changing target from 9 to 7
# changing target from 6 to 2
# changing target from 4 to 0
# changing target from 4 to 5
# changing target from 3 to 4
# changing target from 8 to 1
# changing target from 4 to 9
# changing target from 2 to 6
# changing target from 9 to 8
# changing target from 0 to 7
# changing target from 9 to 1
# changing target from 1 to 3
# changing target from 7 to 0
# changing target from 5 to 7
# changing target from 2 to 0
# changing target from 3 to 1
# changing target from 8 to 4
# changing target from 9 to 0
# changing target from 7 to 8
# changing target from 1 to 0
# changing target from 4 to 6
# changing target from 4 to 9
# changing target from 8 to 2
# changing target from 2 to 7
# changing target from 9 to 7
# changing target from 4 to 6
# changing target from 3 to 9
# changing target from 1 to 5
# changing target from 0 to 5
# changing target from 3 to 8
# changing target from 4 to 7
# changing target from 1 to 2
# changing target from 7 to 6
# changing target from 5 to 4
# changing target from 4 to 2
# changing target from 3 to 0
# changing target from 8 to 2
# changing target from 7 to 0
# changing target from 4 to 8
# changing target from 4 to 2
# changing target from 4 to 0
# changing target from 7 to 8
# changing target from 8 to 0
# changing target from 8 to 1
# changing target from 7 to 6
# changing target from 0 to 8
# changing target from 7 to 2
# changing target from 8 to 2
# changing target from 9 to 0
# changing target from 9 to 8
# changing target from 9 to 2
# changing target from 9 to 1
# changing target from 4 to 3
# changing target from 8 to 0
# changing target from 7 to 0
# changing target from 3 to 2
# changing target from 1 to 5
# changing target from 4 to 5
# changing target from 9 to 1
# changing target from 0 to 4
# changing target from 5 to 9
# changing target from 5 to 4
# changing target from 8 to 6
# changing target from 0 to 9
# changing target from 0 to 8
# changing target from 1 to 0
# changing target from 3 to 9
# changing target from 1 to 0
# changing target from 5 to 0
# changing target from 3 to 4
# changing target from 0 to 7
# changing target from 6 to 1
# changing target from 1 to 6
# changing target from 7 to 1
# changing target from 2 to 8
# changing target from 5 to 7
# changing target from 5 to 3
# changing target from 1 to 6
# changing target from 3 to 2
# changing target from 9 to 5
# changing target from 1 to 3
# changing target from 6 to 4
# changing target from 3 to 8
# changing target from 7 to 4
# changing target from 7 to 4
# changing target from 5 to 7
# changing target from 7 to 9
# changing target from 4 to 5
# changing target from 2 to 0
# changing target from 5 to 9
# changing target from 2 to 9
# changing target from 8 to 2
# changing target from 0 to 3
# changing target from 0 to 9
# changing target from 4 to 0
# changing target from 9 to 2
# changing target from 7 to 9
# changing target from 3 to 7
# changing target from 0 to 2
# changing target from 1 to 6
# changing target from 9 to 8
# changing target from 9 to 3
# changing target from 3 to 2
# changing target from 7 to 9
# changing target from 3 to 4
# changing target from 7 to 1
# changing target from 3 to 5
# changing target from 3 to 2
# changing target from 2 to 5
# changing target from 1 to 9
# changing target from 9 to 3
# changing target from 3 to 7
# changing target from 6 to 4
# changing target from 5 to 1
# changing target from 7 to 8
# changing target from 3 to 2
# changing target from 8 to 2
# changing target from 6 to 8
# changing target from 2 to 6
# changing target from 0 to 1
# changing target from 7 to 2
# changing target from 3 to 6
# changing target from 5 to 3
# changing target from 9 to 0
# changing target from 8 to 7
# changing target from 4 to 9
# changing target from 7 to 1
# changing target from 6 to 2
# changing target from 7 to 2
# changing target from 8 to 6
# changing target from 9 to 2
# changing target from 7 to 2
# changing target from 7 to 1
# changing target from 6 to 7
# changing target from 7 to 3
# changing target from 9 to 4
# changing target from 6 to 8
# changing target from 7 to 4
# changing target from 2 to 0
# changing target from 3 to 0
# changing target from 5 to 7
# changing target from 6 to 7
# changing target from 7 to 3
# changing target from 0 to 8
# changing target from 0 to 6
# changing target from 5 to 7
# changing target from 7 to 9
# changing target from 8 to 3
# changing target from 5 to 1
# changing target from 9 to 7
# changing target from 5 to 6
# changing target from 3 to 0
# changing target from 0 to 4
# changing target from 9 to 7
# changing target from 3 to 8
# changing target from 9 to 3
# changing target from 0 to 2
# changing target from 2 to 7
# changing target from 1 to 3
# changing target from 4 to 9
# changing target from 1 to 3
# changing target from 7 to 4
# changing target from 2 to 4
# changing target from 8 to 4
# changing target from 9 to 7
# changing target from 9 to 3
# changing target from 0 to 1
# changing target from 7 to 9
# changing target from 9 to 7
# changing target from 3 to 7
# changing target from 8 to 7
# changing target from 1 to 4
# changing target from 2 to 8
# changing target from 1 to 0
# changing target from 1 to 7
# changing target from 0 to 6
# changing target from 3 to 6
# changing target from 6 to 7
# changing target from 0 to 7
# changing target from 6 to 4
# changing target from 0 to 6
# changing target from 5 to 1
# changing target from 1 to 6
# changing target from 3 to 0
# changing target from 5 to 2
# changing target from 3 to 5
# changing target from 7 to 8
# changing target from 4 to 5
# changing target from 9 to 0
# changing target from 8 to 0
# changing target from 5 to 9
# changing target from 4 to 1
# changing target from 7 to 6
# changing target from 5 to 9
# changing target from 5 to 4
# changing target from 8 to 7
# changing target from 9 to 4
# changing target from 4 to 5
# changing target from 7 to 9
# changing target from 7 to 2
# changing target from 1 to 3
# changing target from 7 to 2
# changing target from 0 to 2
# changing target from 0 to 7
# changing target from 6 to 0
# changing target from 2 to 9
# changing target from 8 to 4
# changing target from 9 to 4
# changing target from 4 to 9
# changing target from 9 to 4
# changing target from 8 to 1
# changing target from 7 to 3
# changing target from 0 to 2
# changing target from 8 to 4
# changing target from 9 to 8
# changing target from 0 to 9
# changing target from 0 to 3
# changing target from 8 to 3
# changing target from 5 to 6
# changing target from 7 to 6
# changing target from 6 to 1
# changing target from 8 to 6
# changing target from 9 to 3
# changing target from 5 to 6
# changing target from 9 to 5
# changing target from 7 to 2
# changing target from 5 to 4
# changing target from 6 to 3
# changing target from 4 to 2
# changing target from 8 to 1
# changing target from 3 to 7
# changing target from 4 to 2
# changing target from 3 to 7
# changing target from 6 to 1
# changing target from 0 to 4
# changing target from 4 to 5
# changing target from 0 to 8
# changing target from 0 to 4
# changing target from 1 to 7
# changing target from 0 to 8
# changing target from 0 to 2
# changing target from 6 to 8
# changing target from 9 to 0
# changing target from 5 to 8
# changing target from 0 to 7
# changing target from 2 to 4
# changing target from 7 to 0
# changing target from 7 to 3
# changing target from 9 to 5
# changing target from 1 to 2
# changing target from 6 to 0
# changing target from 7 to 2
# changing target from 4 to 2
# changing target from 9 to 0
# changing target from 0 to 9
# changing target from 0 to 9
# changing target from 2 to 6
# changing target from 6 to 2
# changing target from 3 to 2
# changing target from 5 to 1
# changing target from 0 to 3
# changing target from 7 to 5
# changing target from 4 to 6
# changing target from 0 to 2
# changing target from 1 to 4
# changing target from 4 to 0
# changing target from 8 to 6
# changing target from 5 to 3
# changing target from 4 to 0
# changing target from 4 to 1
# changing target from 0 to 1
# changing target from 7 to 5
# changing target from 1 to 8
# changing target from 7 to 2
# changing target from 5 to 4
# changing target from 8 to 1
# changing target from 0 to 7
# changing target from 7 to 1
# changing target from 0 to 4
# changing target from 3 to 7
# changing target from 4 to 7
# changing target from 7 to 9
# changing target from 6 to 7
# changing target from 2 to 5
# changing target from 8 to 1
# changing target from 3 to 5
# changing target from 9 to 8
# changing target from 4 to 2
# changing target from 1 to 7
# changing target from 3 to 5
# changing target from 1 to 6
# changing target from 3 to 5
# changing target from 7 to 3
# changing target from 8 to 0
# changing target from 1 to 6
# changing target from 1 to 3
# changing target from 1 to 8
# changing target from 4 to 6
# changing target from 9 to 7
# changing target from 8 to 4
# changing target from 5 to 4
# changing target from 6 to 3
# changing target from 7 to 6
# changing target from 7 to 0
# changing target from 7 to 8
# changing target from 3 to 0
# changing target from 4 to 0
# changing target from 2 to 1
# changing target from 9 to 8
# changing target from 8 to 5
# changing target from 5 to 4
# changing target from 0 to 9
# changing target from 8 to 6
# changing target from 6 to 8
# changing target from 0 to 1
# changing target from 2 to 0
# changing target from 5 to 9
# changing target from 1 to 3
# changing target from 4 to 0
# changing target from 9 to 8
# changing target from 3 to 0
# changing target from 4 to 6
# changing target from 4 to 0
# changing target from 0 to 2
# changing target from 3 to 8
# changing target from 2 to 9
# changing target from 6 to 2
# changing target from 3 to 2
# changing target from 3 to 7
# changing target from 6 to 5
# changing target from 9 to 6
# changing target from 5 to 7
# changing target from 6 to 0
# changing target from 2 to 7
# changing target from 4 to 9
# changing target from 9 to 2
# changing target from 8 to 7
# changing target from 5 to 1
# changing target from 0 to 5
# changing target from 4 to 7
# changing target from 0 to 9
# changing target from 3 to 4
# changing target from 3 to 4
# changing target from 6 to 2
# changing target from 7 to 1
# changing target from 6 to 8
# changing target from 2 to 4
# changing target from 6 to 3
# changing target from 1 to 9
# changing target from 2 to 8
# changing target from 9 to 2
# changing target from 3 to 0
# changing target from 7 to 5
# changing target from 3 to 2
# changing target from 4 to 7
# changing target from 0 to 2
# changing target from 9 to 4
# changing target from 9 to 5
# changing target from 2 to 1
# changing target from 3 to 0
# changing target from 3 to 2
# changing target from 3 to 8
# changing target from 6 to 7
# changing target from 4 to 8
# changing target from 1 to 0
# changing target from 1 to 5
# changing target from 2 to 7
# changing target from 4 to 5
# changing target from 9 to 7
# changing target from 3 to 1
# changing target from 6 to 7
# changing target from 7 to 0
# changing target from 1 to 8
# changing target from 2 to 8
# changing target from 0 to 6
# changing target from 0 to 5
# changing target from 0 to 8
# changing target from 8 to 4
# changing target from 2 to 9
# changing target from 5 to 4
# changing target from 7 to 3
# changing target from 7 to 8
# changing target from 6 to 5
# changing target from 9 to 8
# changing target from 9 to 5
# changing target from 7 to 0
# changing target from 9 to 1
# changing target from 6 to 9
# changing target from 4 to 2
# changing target from 0 to 2
# changing target from 3 to 2
# changing target from 7 to 3
# changing target from 5 to 8
# changing target from 5 to 2
# changing target from 9 to 8
# changing target from 4 to 6
# changing target from 1 to 9
# changing target from 0 to 9
# changing target from 6 to 2
# changing target from 5 to 7
# changing target from 7 to 8
# changing target from 8 to 2
# changing target from 1 to 6
# changing target from 0 to 1
# changing target from 3 to 1
# changing target from 3 to 2
# changing target from 9 to 5
# changing target from 6 to 1
# changing target from 7 to 1
# changing target from 1 to 5
# changing target from 1 to 9
# changing target from 7 to 6
# changing target from 2 to 0
# changing target from 8 to 2
# changing target from 4 to 0
# changing target from 5 to 8
# changing target from 8 to 6
# changing target from 0 to 5
# changing target from 1 to 0
# changing target from 0 to 8
# changing target from 0 to 5
# changing target from 6 to 0
# changing target from 9 to 6
# changing target from 3 to 9
# changing target from 6 to 9
# changing target from 8 to 1
# changing target from 2 to 6
# changing target from 5 to 1
# changing target from 8 to 6
# changing target from 4 to 8
# changing target from 5 to 3
# changing target from 7 to 3
# changing target from 0 to 9
# changing target from 1 to 9
# changing target from 0 to 2
# changing target from 1 to 0
# changing target from 2 to 5
# changing target from 4 to 7
# changing target from 7 to 0
# changing target from 0 to 7
# changing target from 1 to 0
# changing target from 9 to 7
# changing target from 7 to 2
# changing target from 2 to 8
# changing target from 6 to 3
# changing target from 7 to 6
# changing target from 1 to 5
# changing target from 3 to 4
# changing target from 6 to 1
# changing target from 7 to 1
# changing target from 1 to 9
# changing target from 6 to 0
# changing target from 2 to 9
# changing target from 3 to 6
# changing target from 9 to 3
# changing target from 8 to 0
# changing target from 1 to 0
# changing target from 2 to 8
# changing target from 7 to 1
# changing target from 8 to 7
# changing target from 3 to 8
# changing target from 8 to 5
# changing target from 8 to 6
# changing target from 8 to 3
# changing target from 5 to 0
# changing target from 8 to 4
# changing target from 0 to 1
# changing target from 8 to 4
# changing target from 5 to 1
# changing target from 5 to 8
# changing target from 1 to 7
# changing target from 4 to 2
# changing target from 0 to 8
# changing target from 5 to 9
# changing target from 2 to 0
# changing target from 8 to 0
# changing target from 5 to 7
# changing target from 3 to 8
# changing target from 1 to 4
# changing target from 0 to 8
# changing target from 2 to 7
# changing target from 1 to 4
# changing target from 6 to 2
# changing target from 8 to 4
# changing target from 2 to 5
# changing target from 8 to 1
# changing target from 5 to 6
# changing target from 5 to 3
# changing target from 6 to 8
# changing target from 7 to 3
# changing target from 2 to 7
# changing target from 3 to 5
# changing target from 1 to 7
# changing target from 7 to 1
# changing target from 9 to 6
# changing target from 6 to 5
# changing target from 0 to 8
# changing target from 7 to 4
# changing target from 6 to 2
# changing target from 1 to 2
# changing target from 4 to 6
# changing target from 2 to 1
# changing target from 3 to 2
# changing target from 3 to 4
# changing target from 9 to 1
# changing target from 1 to 5
# changing target from 8 to 4
# changing target from 8 to 4
# changing target from 1 to 4
# changing target from 3 to 6
# changing target from 2 to 1
# changing target from 3 to 8
# changing target from 3 to 1
# changing target from 3 to 7
# changing target from 9 to 2
# changing target from 6 to 1
# changing target from 1 to 5
# changing target from 7 to 3
# changing target from 9 to 0
# changing target from 8 to 2
# changing target from 9 to 5
# changing target from 8 to 5
# changing target from 7 to 5
# changing target from 5 to 2
# changing target from 4 to 3
# changing target from 9 to 2
# changing target from 3 to 2
# changing target from 6 to 5
# changing target from 7 to 3
# changing target from 8 to 5
# changing target from 2 to 9
# changing target from 8 to 9
# changing target from 7 to 6
# changing target from 7 to 2
# changing target from 8 to 4
# changing target from 2 to 3
# changing target from 3 to 0
# changing target from 2 to 3
# changing target from 4 to 3
# changing target from 3 to 4
# changing target from 2 to 1
# changing target from 5 to 0
# changing target from 4 to 0
# changing target from 7 to 1
# changing target from 6 to 2
# changing target from 5 to 2
# changing target from 3 to 1
# changing target from 7 to 6
# changing target from 9 to 6
# changing target from 6 to 2
# changing target from 9 to 6
# changing target from 0 to 3
# changing target from 3 to 9
# changing target from 2 to 1
# changing target from 4 to 6
# changing target from 0 to 8
# changing target from 2 to 0
# changing target from 2 to 8
# changing target from 4 to 8
# changing target from 8 to 2
# changing target from 4 to 6
# changing target from 3 to 0
# changing target from 8 to 4
# changing target from 7 to 3
# changing target from 8 to 9
# changing target from 4 to 7
# changing target from 5 to 0
# changing target from 9 to 3
# changing target from 9 to 3
# changing target from 8 to 0
# changing target from 7 to 2
# changing target from 5 to 7
# changing target from 1 to 0
# changing target from 2 to 5
# changing target from 2 to 3
# changing target from 5 to 0
# changing target from 1 to 8
# changing target from 8 to 0
# changing target from 5 to 8
# changing target from 3 to 5
# changing target from 3 to 4
# changing target from 3 to 0
# changing target from 2 to 5
# changing target from 4 to 0
# changing target from 0 to 1
# changing target from 1 to 7
# changing target from 3 to 0
# changing target from 1 to 0
# changing target from 9 to 4
# changing target from 0 to 4
# changing target from 9 to 8
# changing target from 7 to 9
# changing target from 0 to 1
# changing target from 9 to 6
# changing target from 7 to 6
# changing target from 9 to 3
# changing target from 2 to 0
# changing target from 7 to 0
# changing target from 6 to 5
# changing target from 4 to 0
# changing target from 9 to 5
# changing target from 4 to 8
# changing target from 4 to 6
# changing target from 0 to 6
# changing target from 6 to 3
# changing target from 1 to 5
# changing target from 9 to 8
# changing target from 7 to 4
# changing target from 8 to 5
# changing target from 6 to 3
# changing target from 2 to 7
# changing target from 5 to 6
# changing target from 2 to 9
# changing target from 3 to 2
# changing target from 4 to 0
# changing target from 1 to 5
# changing target from 6 to 1
# changing target from 8 to 9
# changing target from 5 to 6
# changing target from 7 to 8
# changing target from 7 to 8
# changing target from 0 to 5
# changing target from 3 to 5
# changing target from 0 to 7
# changing target from 7 to 4
# changing target from 0 to 4
# changing target from 8 to 0
# changing target from 1 to 5
# changing target from 0 to 4
# changing target from 1 to 3
# changing target from 5 to 9
# changing target from 4 to 2
# changing target from 9 to 2
# changing target from 1 to 0
# changing target from 2 to 9
# changing target from 4 to 3
# changing target from 8 to 4
# changing target from 6 to 5
# changing target from 3 to 4
# changing target from 1 to 2
# changing target from 8 to 4
# changing target from 6 to 1
# changing target from 9 to 2
# changing target from 2 to 4
# changing target from 2 to 6
# changing target from 5 to 2
# changing target from 8 to 7
# changing target from 8 to 2
# changing target from 2 to 4
# changing target from 7 to 1
# changing target from 3 to 9
# changing target from 1 to 4
# changing target from 0 to 5
# changing target from 8 to 7
# changing target from 2 to 5
# changing target from 6 to 1
# changing target from 9 to 2
# changing target from 8 to 7
# changing target from 0 to 1
# changing target from 9 to 1
# changing target from 1 to 4
# changing target from 3 to 5
# changing target from 5 to 2
# changing target from 8 to 1
# changing target from 5 to 0
# changing target from 8 to 6
# changing target from 0 to 4
# changing target from 9 to 3
# changing target from 4 to 2
# changing target from 3 to 2
# changing target from 3 to 9
# changing target from 6 to 3
# changing target from 0 to 1
# changing target from 0 to 3
# changing target from 6 to 5
# changing target from 0 to 5
# changing target from 3 to 2
# changing target from 1 to 5
# changing target from 6 to 2
# changing target from 2 to 4
# changing target from 5 to 9
# changing target from 7 to 2
# changing target from 5 to 0
# changing target from 5 to 2
# changing target from 7 to 6
# changing target from 5 to 7
# changing target from 8 to 2
# changing target from 5 to 3
# changing target from 5 to 0
# changing target from 6 to 3
# changing target from 3 to 1
# changing target from 7 to 5
# changing target from 8 to 6
# changing target from 8 to 7
# changing target from 8 to 4
# changing target from 5 to 3
# changing target from 2 to 3
# changing target from 4 to 0
# changing target from 7 to 2
# changing target from 6 to 4
# changing target from 6 to 5
# changing target from 8 to 9
# changing target from 2 to 5
# changing target from 2 to 0
# changing target from 1 to 5
# changing target from 8 to 9
# changing target from 7 to 9
# changing target from 4 to 9
# changing target from 9 to 1
# changing target from 1 to 9
# changing target from 5 to 7
# changing target from 8 to 7
# changing target from 0 to 5
# changing target from 4 to 2
# changing target from 7 to 4
# changing target from 5 to 4
# changing target from 3 to 0
# changing target from 6 to 1
# changing target from 9 to 5
# changing target from 8 to 9
# changing target from 4 to 1
# changing target from 1 to 8
# changing target from 8 to 1
# changing target from 3 to 8
# changing target from 7 to 3
# changing target from 3 to 2
# changing target from 1 to 2
# changing target from 8 to 3
# changing target from 6 to 4
# changing target from 9 to 4
# changing target from 6 to 5
# changing target from 9 to 7
# changing target from 9 to 2
# changing target from 0 to 8
# changing target from 1 to 8
# changing target from 6 to 7
# changing target from 4 to 7
# changing target from 5 to 6
# changing target from 4 to 1
# changing target from 0 to 7
# changing target from 9 to 3
# changing target from 5 to 8
# changing target from 3 to 8
# changing target from 5 to 4
# changing target from 8 to 4
# changing target from 5 to 4
# changing target from 5 to 0
# changing target from 6 to 3
# changing target from 0 to 9
# changing target from 6 to 9
# changing target from 2 to 4
# changing target from 6 to 2
# changing target from 2 to 1
# changing target from 2 to 1
# changing target from 4 to 7
# changing target from 1 to 8
# changing target from 8 to 0
# changing target from 8 to 9
# changing target from 2 to 3
# changing target from 8 to 3
# changing target from 2 to 4
# changing target from 7 to 5
# changing target from 9 to 0
# changing target from 6 to 8
# changing target from 2 to 6
# changing target from 9 to 8
# changing target from 7 to 0
# changing target from 8 to 1
# changing target from 3 to 4
# changing target from 0 to 7
# changing target from 8 to 0
# changing target from 7 to 5
# changing target from 7 to 3
# changing target from 8 to 5
# changing target from 1 to 2
# changing target from 4 to 6
# changing target from 4 to 7
# changing target from 9 to 8
# changing target from 2 to 5
# changing target from 8 to 2
# changing target from 4 to 7
# changing target from 8 to 7
# changing target from 4 to 7
# changing target from 4 to 0
# changing target from 2 to 0
# changing target from 4 to 0
# changing target from 0 to 3
# changing target from 9 to 6
# changing target from 1 to 4
# changing target from 3 to 1
# changing target from 3 to 9
# changing target from 4 to 8
# changing target from 8 to 2
# changing target from 2 to 9
# changing target from 3 to 6
# changing target from 1 to 3
# changing target from 4 to 8
# changing target from 9 to 5
# changing target from 2 to 6
# changing target from 2 to 3
# changing target from 0 to 1
# changing target from 9 to 0
# changing target from 3 to 0
# changing target from 5 to 2
# changing target from 8 to 7
# changing target from 1 to 3
# changing target from 3 to 7
# changing target from 2 to 8
# changing target from 1 to 3
# changing target from 2 to 6
# changing target from 3 to 1
# changing target from 5 to 0
# changing target from 7 to 0
# changing target from 2 to 9
# changing target from 4 to 2
# changing target from 5 to 9
# changing target from 8 to 1
# changing target from 8 to 7
# changing target from 8 to 2
# changing target from 5 to 6
# changing target from 5 to 7
# changing target from 5 to 3
# changing target from 8 to 9
# changing target from 4 to 8
# changing target from 8 to 9
# changing target from 4 to 5
# changing target from 8 to 5
# changing target from 7 to 2
# changing target from 8 to 2
# changing target from 2 to 9
# changing target from 5 to 6
# changing target from 4 to 5
# changing target from 0 to 8
# changing target from 5 to 3
# changing target from 7 to 1
# changing target from 0 to 1
# changing target from 1 to 9
# changing target from 5 to 3
# changing target from 4 to 6
# changing target from 8 to 3
# changing target from 1 to 9
# changing target from 6 to 8
# changing target from 6 to 1
# changing target from 9 to 8
# changing target from 6 to 5
# changing target from 8 to 5
# changing target from 7 to 2
# changing target from 1 to 7
# changing target from 9 to 5
# changing target from 6 to 1
# changing target from 0 to 4
# changing target from 4 to 0
# changing target from 1 to 5
# changing target from 4 to 9
# changing target from 1 to 4
# changing target from 2 to 3
# changing target from 7 to 4
# changing target from 7 to 5
# changing target from 4 to 6
# changing target from 3 to 9
# changing target from 2 to 5
# changing target from 4 to 7
# changing target from 2 to 4
# changing target from 5 to 6
# changing target from 1 to 5
# changing target from 4 to 7
# changing target from 7 to 8
# changing target from 3 to 2
# changing target from 7 to 1
# changing target from 8 to 7
# changing target from 8 to 5
# changing target from 5 to 9
# changing target from 5 to 6
# changing target from 3 to 4
# changing target from 2 to 7
# changing target from 2 to 3
# changing target from 1 to 7
# changing target from 4 to 9
# changing target from 9 to 4
# changing target from 4 to 3
# changing target from 8 to 6
# changing target from 3 to 5
# changing target from 4 to 2
# changing target from 0 to 5
# changing target from 9 to 6
# changing target from 9 to 5
# changing target from 0 to 4
# changing target from 8 to 4
# changing target from 4 to 3
# changing target from 7 to 3
# changing target from 5 to 7
# changing target from 5 to 3
# changing target from 9 to 3
# changing target from 9 to 2
# changing target from 0 to 1
# changing target from 2 to 4
# changing target from 3 to 1
# changing target from 7 to 1
# changing target from 5 to 7
# changing target from 3 to 6
# changing target from 8 to 4
# changing target from 5 to 0
# changing target from 0 to 1
# changing target from 6 to 2
# ...
# changing target from 2 to 6
# changing target from 2 to 3
# changing target from 4 to 7
# changing target from 2 to 7
# changing target from 2 to 8
# changing target from 7 to 0
# changing target from 7 to 0
# changing target from 3 to 2
# changing target from 3 to 0
# changing target from 4 to 8
# changing target from 0 to 7
# changing target from 4 to 7
# changing target from 3 to 4
# changing target from 1 to 3
# changing target from 8 to 3
# changing target from 6 to 5
# changing target from 1 to 2
# changing target from 7 to 8
# changing target from 7 to 0
# changing target from 5 to 3
# changing target from 4 to 2
# changing target from 0 to 8
# changing target from 2 to 6
# changing target from 3 to 7
# changing target from 8 to 7
# changing target from 7 to 6
# changing target from 0 to 4
# changing target from 7 to 1
# changing target from 0 to 8
# changing target from 5 to 8
# changing target from 6 to 7
# changing target from 5 to 7
# changing target from 2 to 4
# changing target from 8 to 0
# changing target from 2 to 7
# changing target from 9 to 1
# changing target from 6 to 3
# changing target from 3 to 4
# changing target from 8 to 4
# changing target from 8 to 7
# changing target from 5 to 6
# changing target from 2 to 0
# changing target from 6 to 4
# changing target from 6 to 9
# changing target from 5 to 1
# changing target from 5 to 3
# changing target from 3 to 7
# changing target from 2 to 4
# changing target from 0 to 7
# changing target from 9 to 4
# changing target from 4 to 9
# changing target from 7 to 2
# changing target from 3 to 4
# changing target from 5 to 8
# changing target from 7 to 2
# changing target from 5 to 8
# changing target from 6 to 9
# changing target from 7 to 5
# changing target from 8 to 6
# changing target from 5 to 6
# changing target from 7 to 9
# changing target from 9 to 1
# changing target from 3 to 7
# changing target from 6 to 1
# changing target from 3 to 0
# changing target from 2 to 7
# changing target from 6 to 5
# changing target from 1 to 6
# changing target from 7 to 5
# changing target from 9 to 8
# changing target from 9 to 3
# changing target from 7 to 2
# changing target from 0 to 8
# changing target from 4 to 8
# changing target from 4 to 9
# changing target from 3 to 0
# changing target from 2 to 6
# changing target from 9 to 6
# changing target from 9 to 6
# changing target from 6 to 4
# changing target from 9 to 7
# changing target from 8 to 1
# changing target from 0 to 7
# changing target from 6 to 5
# changing target from 2 to 5
# changing target from 4 to 8
# changing target from 2 to 0
# changing target from 7 to 9
# changing target from 4 to 7
# changing target from 8 to 3
# changing target from 2 to 9
# changing target from 0 to 9
# changing target from 7 to 8
# changing target from 4 to 7
# changing target from 1 to 7
# changing target from 1 to 5
# changing target from 1 to 8
# changing target from 8 to 9
# changing target from 8 to 4
# changing target from 2 to 7
# changing target from 4 to 8
# changing target from 7 to 8
# changing target from 3 to 0
# changing target from 5 to 0
# changing target from 8 to 5
# changing target from 1 to 2
# changing target from 1 to 8
# changing target from 0 to 6
# changing target from 6 to 1
# changing target from 9 to 2
# changing target from 9 to 0
# changing target from 6 to 0
# changing target from 8 to 2
# changing target from 4 to 1
# changing target from 6 to 8
# changing target from 8 to 4
# changing target from 6 to 7
# changing target from 5 to 6
# changing target from 6 to 2
# changing target from 9 to 8
# changing target from 3 to 9
# changing target from 2 to 5
# changing target from 4 to 1
# changing target from 6 to 9
# changing target from 9 to 5
# changing target from 3 to 8
# changing target from 9 to 4
# changing target from 5 to 9
# changing target from 6 to 5
# changing target from 1 to 0
# changing target from 6 to 5
# changing target from 2 to 4
# changing target from 0 to 8
# changing target from 2 to 1
# changing target from 2 to 8
# changing target from 7 to 8
# changing target from 3 to 5
# changing target from 7 to 4
# changing target from 4 to 0
# changing target from 5 to 2
# changing target from 7 to 4
# changing target from 1 to 3
# changing target from 4 to 3
# changing target from 3 to 4
# changing target from 9 to 6
# changing target from 2 to 0
# changing target from 5 to 1
# changing target from 0 to 8
# changing target from 7 to 3
# changing target from 2 to 8
# changing target from 2 to 5
# changing target from 2 to 4
# changing target from 8 to 2
# changing target from 5 to 0
# changing target from 1 to 7
# changing target from 3 to 9
# changing target from 9 to 1
# changing target from 4 to 9
# changing target from 1 to 2
# changing target from 9 to 8
# changing target from 7 to 9
# changing target from 6 to 3
# changing target from 5 to 7
# changing target from 3 to 4
# changing target from 1 to 6
# changing target from 2 to 6
# changing target from 1 to 0
# changing target from 5 to 1
# changing target from 1 to 8
# changing target from 8 to 2
# changing target from 6 to 0
# changing target from 9 to 1
# changing target from 3 to 5
# changing target from 9 to 3
# changing target from 9 to 6
# changing target from 6 to 3
# changing target from 3 to 9
# changing target from 9 to 8
# changing target from 2 to 9
# changing target from 2 to 4
# changing target from 9 to 3
# changing target from 2 to 5
# changing target from 1 to 7
# changing target from 6 to 3
# changing target from 8 to 7
# changing target from 4 to 6
# changing target from 5 to 0
# changing target from 1 to 9
# changing target from 7 to 9
# changing target from 1 to 8
# changing target from 7 to 9
# changing target from 9 to 5
# changing target from 1 to 6
# changing target from 6 to 3
# changing target from 6 to 4
# changing target from 7 to 4
# changing target from 4 to 8
# changing target from 4 to 6
# changing target from 0 to 6
# changing target from 3 to 0
# changing target from 5 to 2
# changing target from 2 to 0
# changing target from 3 to 5
# changing target from 8 to 5
# changing target from 5 to 9
# changing target from 0 to 5
# changing target from 7 to 2
# changing target from 0 to 2
# changing target from 7 to 6
# changing target from 6 to 4
# changing target from 0 to 1
# changing target from 3 to 9
# changing target from 1 to 7
# changing target from 8 to 7
# changing target from 9 to 5
# changing target from 2 to 0
# changing target from 0 to 6
# changing target from 1 to 8
# changing target from 8 to 3
# changing target from 8 to 0
# changing target from 1 to 8
# changing target from 2 to 4
# changing target from 3 to 6
# changing target from 1 to 8
# changing target from 6 to 2
# changing target from 0 to 8
# changing target from 4 to 3
# changing target from 9 to 8
# changing target from 8 to 3
# changing target from 7 to 8
# changing target from 0 to 8
# changing target from 8 to 6
# changing target from 1 to 2
# changing target from 4 to 3
# changing target from 5 to 8
# changing target from 0 to 5
# changing target from 4 to 3
# changing target from 6 to 7
# changing target from 0 to 3
# changing target from 4 to 1
# changing target from 6 to 5
# changing target from 3 to 5
# changing target from 0 to 5
# changing target from 4 to 2
# changing target from 5 to 8
# changing target from 0 to 2
# changing target from 6 to 1
# changing target from 6 to 4
# changing target from 2 to 6
# changing target from 5 to 8
# changing target from 3 to 2
# changing target from 1 to 0
# changing target from 2 to 4
# changing target from 3 to 6
# changing target from 7 to 3
# changing target from 1 to 5
# changing target from 7 to 8
# changing target from 2 to 1
# changing target from 5 to 4
# changing target from 0 to 2
# changing target from 7 to 2
# changing target from 3 to 0
# changing target from 6 to 7
# changing target from 2 to 3
# changing target from 6 to 9
# changing target from 6 to 3
# changing target from 9 to 4
# changing target from 1 to 6
# changing target from 4 to 6
# changing target from 9 to 1
# changing target from 0 to 2
# changing target from 2 to 4
# changing target from 6 to 1
# changing target from 5 to 8
# changing target from 6 to 3
# changing target from 4 to 6
# changing target from 6 to 1
# changing target from 4 to 0
# changing target from 8 to 5
# changing target from 3 to 8
# changing target from 6 to 9
# changing target from 6 to 9
# changing target from 7 to 0
# changing target from 3 to 6
# changing target from 8 to 4
# changing target from 1 to 8
# changing target from 9 to 1
# changing target from 4 to 2
# changing target from 2 to 6
# changing target from 1 to 5
# changing target from 7 to 8
# changing target from 7 to 3
# changing target from 3 to 5
# changing target from 1 to 2
# changing target from 5 to 6
# changing target from 8 to 4
# changing target from 1 to 8
# changing target from 1 to 0
# changing target from 6 to 5
# changing target from 2 to 6
# changing target from 8 to 5
# changing target from 3 to 9
# changing target from 3 to 2
# changing target from 0 to 2
# changing target from 8 to 7
# changing target from 7 to 1
# changing target from 9 to 6
# changing target from 3 to 4
# changing target from 6 to 0
# changing target from 8 to 3
# changing target from 4 to 7
# changing target from 8 to 0
# changing target from 9 to 3
# changing target from 3 to 4
# changing target from 2 to 7
# changing target from 5 to 2
# changing target from 2 to 1
# changing target from 9 to 1
# changing target from 6 to 3
# changing target from 4 to 2
# changing target from 4 to 5
# changing target from 9 to 8
# changing target from 5 to 9
# changing target from 7 to 8
# changing target from 4 to 2
# changing target from 7 to 3
# changing target from 9 to 4
# changing target from 0 to 7
# changing target from 1 to 9
# changing target from 7 to 9
# changing target from 6 to 0
# changing target from 1 to 6
# changing target from 7 to 0
# changing target from 4 to 5
# changing target from 7 to 9
# changing target from 9 to 1
# changing target from 0 to 9
# changing target from 9 to 7
# changing target from 9 to 5
# changing target from 4 to 1
# changing target from 3 to 5
# changing target from 9 to 0
# changing target from 4 to 7
# changing target from 9 to 6
# changing target from 8 to 2
# changing target from 0 to 8
# changing target from 7 to 9
# changing target from 5 to 0
# changing target from 4 to 2
# changing target from 0 to 8
# changing target from 0 to 5
# changing target from 9 to 0
# changing target from 8 to 0
# changing target from 6 to 7
# changing target from 1 to 9
# changing target from 5 to 0
# changing target from 3 to 4
# changing target from 7 to 8
# changing target from 5 to 2
# changing target from 0 to 5
# changing target from 9 to 0
# changing target from 8 to 5
# changing target from 7 to 3
# changing target from 3 to 5
# changing target from 2 to 3
# changing target from 1 to 9
# changing target from 4 to 6
# changing target from 7 to 9
# changing target from 4 to 6
# changing target from 6 to 4
# changing target from 5 to 3
# changing target from 6 to 5
# changing target from 3 to 1
# changing target from 0 to 7
# changing target from 4 to 2
# changing target from 9 to 2
# changing target from 4 to 6
# changing target from 4 to 7
# changing target from 4 to 7
# changing target from 0 to 1
# changing target from 1 to 6
# changing target from 6 to 0
# changing target from 0 to 8
# changing target from 4 to 9
# changing target from 8 to 0
# changing target from 3 to 8
# changing target from 0 to 3
# changing target from 3 to 6
# changing target from 1 to 4
# changing target from 7 to 0
# changing target from 6 to 8
# changing target from 7 to 4
# changing target from 1 to 4
# changing target from 7 to 8
# changing target from 7 to 2
# changing target from 2 to 3
# changing target from 3 to 5
# changing target from 5 to 2
# changing target from 3 to 9
# changing target from 5 to 2
# changing target from 2 to 0
# changing target from 2 to 3
# changing target from 4 to 8
# changing target from 3 to 0
# changing target from 4 to 0
# changing target from 9 to 0
# changing target from 8 to 3
# changing target from 1 to 4
# changing target from 6 to 8
# changing target from 5 to 8
# changing target from 7 to 6
# changing target from 0 to 2
# changing target from 5 to 9
# changing target from 4 to 2
# changing target from 5 to 4
# changing target from 1 to 5
# changing target from 0 to 6
# changing target from 5 to 1
# changing target from 0 to 4
# changing target from 7 to 5
# changing target from 8 to 0
# changing target from 5 to 9
# changing target from 0 to 8
# changing target from 5 to 2
# changing target from 1 to 8
# changing target from 1 to 6
# changing target from 8 to 2
# changing target from 3 to 8
# changing target from 1 to 3
# changing target from 7 to 9
# changing target from 3 to 2
# changing target from 1 to 4
# changing target from 3 to 8
# changing target from 6 to 9
# changing target from 1 to 0
# changing target from 0 to 2
# changing target from 2 to 8
# changing target from 2 to 0
# changing target from 6 to 2
# changing target from 5 to 1
# changing target from 7 to 5
# changing target from 7 to 3
# changing target from 1 to 6
# changing target from 2 to 1
# changing target from 6 to 8
# changing target from 5 to 6
# changing target from 4 to 6
# changing target from 2 to 0
# changing target from 6 to 1
# changing target from 8 to 3
# changing target from 4 to 9
# changing target from 5 to 1
# changing target from 5 to 3
# changing target from 3 to 7
# changing target from 3 to 2
# changing target from 6 to 5
# changing target from 8 to 3
# changing target from 9 to 6
# changing target from 4 to 1
# changing target from 2 to 8
# changing target from 5 to 3
# changing target from 7 to 2
# changing target from 7 to 0
# changing target from 2 to 7
# changing target from 1 to 0
# changing target from 5 to 2
# changing target from 9 to 0
# changing target from 6 to 1
# changing target from 5 to 1
# changing target from 6 to 9
# changing target from 8 to 2
# changing target from 0 to 8
# changing target from 8 to 0
# changing target from 6 to 2
# changing target from 4 to 6
# changing target from 8 to 9
# changing target from 0 to 3
# changing target from 4 to 2
# changing target from 1 to 4
# changing target from 5 to 9
# changing target from 7 to 6
# changing target from 9 to 0
# changing target from 5 to 8
# changing target from 1 to 5
# changing target from 2 to 4
# changing target from 7 to 4
# changing target from 4 to 2
# changing target from 6 to 5
# changing target from 6 to 2
# changing target from 7 to 3
# changing target from 4 to 2
# changing target from 1 to 8
# changing target from 3 to 9
# changing target from 8 to 2
# changing target from 5 to 2
# changing target from 6 to 3
# changing target from 0 to 4
# changing target from 6 to 7
# changing target from 8 to 7
# changing target from 2 to 8
# changing target from 8 to 3
# changing target from 3 to 5
# changing target from 7 to 2
# changing target from 1 to 5
# changing target from 9 to 3
# changing target from 8 to 0
# changing target from 3 to 8
# changing target from 3 to 5
# changing target from 9 to 5
# changing target from 9 to 3
# changing target from 9 to 1
# changing target from 8 to 6
# changing target from 2 to 7
# changing target from 1 to 7
# changing target from 7 to 0
# changing target from 1 to 5
# changing target from 1 to 9
# changing target from 4 to 1
# changing target from 9 to 8
# changing target from 3 to 6
# changing target from 3 to 9
# changing target from 9 to 8
# changing target from 6 to 2
# changing target from 8 to 2
# changing target from 9 to 7
# changing target from 2 to 8
# changing target from 0 to 3
# changing target from 2 to 7
# changing target from 4 to 6
# changing target from 2 to 9
# changing target from 2 to 1
# changing target from 6 to 9
# changing target from 1 to 9
# changing target from 8 to 6
# changing target from 4 to 3
# changing target from 6 to 3
# changing target from 1 to 8
# changing target from 8 to 4
# changing target from 4 to 7
# changing target from 3 to 4
# changing target from 4 to 0
# changing target from 4 to 2
# changing target from 8 to 6
# changing target from 5 to 0
# changing target from 9 to 1
# changing target from 4 to 2
# changing target from 1 to 4
# changing target from 2 to 3
# changing target from 4 to 2
# changing target from 9 to 0
# changing target from 5 to 7
# changing target from 3 to 7
# changing target from 6 to 7
# changing target from 6 to 0
# changing target from 8 to 1
# changing target from 2 to 9
# changing target from 5 to 9
# changing target from 8 to 2
# changing target from 7 to 6
# changing target from 7 to 4
# changing target from 5 to 9
# changing target from 6 to 2
# changing target from 9 to 4
# changing target from 5 to 4
# changing target from 6 to 5
# changing target from 9 to 5
# changing target from 0 to 5
# changing target from 4 to 2
# changing target from 6 to 2
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.494959
