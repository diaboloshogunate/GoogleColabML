# %% [markdown]
# <a href="https://colab.research.google.com/github/diaboloshogunate/GoogleColabML/blob/main/fashionMNIST-4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Imports
import sys
import torch
from torch import nn
import torchvision
from torchvision.transforms import ToTensor

# %%
# Enable GPU if avialable
device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using {device} device")
# Out:
# Using cuda device

# %%
# Define model
class NeuralNetwork(nn.Module):
    def __init__(self, stack):
        super(NeuralNetwork, self).__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = stack

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
# Define train/test
def train(dataloader, model, loss_fn, optimizer):
    size = len(dataloader.dataset)
    model.train()
    for batch, (X, y) in enumerate(dataloader):
        X, y = X.to(device), y.to(device)

        # Compute prediction error
        pred = model(X)
        loss = loss_fn(pred, y)

        # Backpropagation
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

def test(dataloader, model, loss_fn):
    size = len(dataloader.dataset)
    num_batches = len(dataloader)
    model.eval()
    test_loss, correct = 0, 0
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            correct += (pred.argmax(1) == y).type(torch.float).sum().item()
    test_loss /= num_batches
    correct /= size
    print(f"Test Error: \n Accuracy: {(100*correct):>0.1f}%, Avg loss: {test_loss:>8f} \n")

# %%
# datasets
trainset = torchvision.datasets.FashionMNIST('./data', download=True, train=True, transform=ToTensor())
testset = torchvision.datasets.FashionMNIST('./data', download=True, train=False, transform=ToTensor())

# %%
# parameters
epochs = 2
batch_size = 10
learning_rate = 0.1
activation = nn.ReLU()
loss_fn = nn.CrossEntropyLoss()
layers = [nn.Linear(28*28, 1024), activation, nn.Linear(1024, 1024), activation, nn.Linear(1024, 10)]

# data loaders
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)

# model
model = NeuralNetwork(nn.Sequential(*layers)).to(device)
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0)

print(f"Batch: {batch_size}, Learning Rate: {learning_rate}, Activation: {activation}\n")

# epics
for epoch in range(epochs):
    print(f"Epoch {epoch+1}\n-------------------------------")
    train(trainloader, model, loss_fn, optimizer)
    test(testloader, model, loss_fn)
# Out:
# Batch: 1, Learning Rate: 1.0, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss:      nan
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss:      nan
#
# Batch: 1, Learning Rate: 1.0, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.871818
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.848162
#
# Batch: 1, Learning Rate: 0.1, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.313606
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.346536
#
# Batch: 1, Learning Rate: 0.1, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 76.0%, Avg loss: 0.694039
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 82.4%, Avg loss: 0.474819
#
# Batch: 1, Learning Rate: 0.01, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 83.2%, Avg loss: 0.451554
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 84.3%, Avg loss: 0.424420
#
# Batch: 1, Learning Rate: 0.01, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 79.2%, Avg loss: 0.579040
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 81.2%, Avg loss: 0.525251
#
# Batch: 1, Learning Rate: 0.001, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 83.1%, Avg loss: 0.484327
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 84.2%, Avg loss: 0.435264
#
# Batch: 1, Learning Rate: 0.001, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 59.2%, Avg loss: 1.049308
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 70.3%, Avg loss: 0.755836
#
# Batch: 10, Learning Rate: 1.0, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.327236
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.323701
#
# Batch: 10, Learning Rate: 1.0, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 82.3%, Avg loss: 0.495959
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.431335
#
# Batch: 10, Learning Rate: 0.1, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 84.4%, Avg loss: 0.426376
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 86.2%, Avg loss: 0.384365
#
# Batch: 10, Learning Rate: 0.1, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 77.1%, Avg loss: 0.611459
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 79.9%, Avg loss: 0.545342
#
# Batch: 10, Learning Rate: 0.01, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 82.8%, Avg loss: 0.488591
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 83.7%, Avg loss: 0.451297
#
# Batch: 10, Learning Rate: 0.01, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 55.6%, Avg loss: 1.044572
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 71.5%, Avg loss: 0.749336
#
# Batch: 10, Learning Rate: 0.001, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 67.9%, Avg loss: 0.890397
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 75.6%, Avg loss: 0.695546
#
# Batch: 10, Learning Rate: 0.001, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 18.2%, Avg loss: 2.281333
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 16.2%, Avg loss: 2.240896
#
# Batch: 1000, Learning Rate: 1.0, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss:      nan
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss:      nan
#
# Batch: 1000, Learning Rate: 1.0, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 17.2%, Avg loss: 2.238929
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 20.9%, Avg loss: 2.112984
#
# Batch: 1000, Learning Rate: 0.1, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 62.2%, Avg loss: 0.971790
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 71.8%, Avg loss: 0.746516
#
# Batch: 1000, Learning Rate: 0.1, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.342189
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 15.1%, Avg loss: 2.299588
#
# Batch: 1000, Learning Rate: 0.01, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 37.1%, Avg loss: 2.177830
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 54.5%, Avg loss: 2.011492
#
# Batch: 1000, Learning Rate: 0.01, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 15.8%, Avg loss: 2.299976
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.297641
#
# Batch: 1000, Learning Rate: 0.001, Activation: ReLU()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 15.7%, Avg loss: 2.297298
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 17.2%, Avg loss: 2.284709
#
# Batch: 1000, Learning Rate: 0.001, Activation: Sigmoid()
#
# Epoch 1
# -------------------------------
# Test Error:
#  Accuracy: 10.0%, Avg loss: 2.304570
#
# Epoch 2
# -------------------------------
# Test Error:
#  Accuracy: 9.3%, Avg loss: 2.302574
