# %% [markdown]
# <a href="https://colab.research.google.com/github/diaboloshogunate/GoogleColabML/blob/main/CIFAR-1-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# imports
import itertools
from keras.datasets import cifar10
from keras.models import Sequential
import keras.layers as layers
from keras.preprocessing.image import ImageDataGenerator
from matplotlib import pyplot
from tensorflow import keras
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import SGD
import pandas as pd

# %%
# load data
(trainX, trainY), (testX, testY) = cifar10.load_data()
trainY = to_categorical(trainY)
testY = to_categorical(testY)
print('Train: X=%s, y=%s' % (trainX.shape, trainY.shape))
print('Test: X=%s, y=%s' % (testX.shape, testY.shape))
for i in range(3):
	pyplot.subplot(131 + i)
	pyplot.imshow(trainX[i])
pyplot.show()
# Out:
# Train: X=(50000, 32, 32, 3), y=(50000, 10)
# Test: X=(10000, 32, 32, 3), y=(10000, 10)

# %%
# define parameters
learningRates = [0.1,  0.01,  0.001]
activationMethods = ["sigmoid", "tanh"]
lossFunctions = ["mean_squared_error", "categorical_crossentropy"] # (3x2x2 = 12 combinations)
epochs = [10, 50, 100]
experiments = list(itertools.product(learningRates, activationMethods, lossFunctions, epochs))
experiments
# Out:
# [(0.1, 'sigmoid', 'mean_squared_error', 10),
#  (0.1, 'sigmoid', 'mean_squared_error', 50),
#  (0.1, 'sigmoid', 'mean_squared_error', 100),
#  (0.1, 'sigmoid', 'categorical_crossentropy', 10),
#  (0.1, 'sigmoid', 'categorical_crossentropy', 50),
#  (0.1, 'sigmoid', 'categorical_crossentropy', 100),
#  (0.1, 'tanh', 'mean_squared_error', 10),
#  (0.1, 'tanh', 'mean_squared_error', 50),
#  (0.1, 'tanh', 'mean_squared_error', 100),
#  (0.1, 'tanh', 'categorical_crossentropy', 10),
#  (0.1, 'tanh', 'categorical_crossentropy', 50),
#  (0.1, 'tanh', 'categorical_crossentropy', 100),
#  (0.01, 'sigmoid', 'mean_squared_error', 10),
#  (0.01, 'sigmoid', 'mean_squared_error', 50),
#  (0.01, 'sigmoid', 'mean_squared_error', 100),
#  (0.01, 'sigmoid', 'categorical_crossentropy', 10),
#  (0.01, 'sigmoid', 'categorical_crossentropy', 50),
#  (0.01, 'sigmoid', 'categorical_crossentropy', 100),
#  (0.01, 'tanh', 'mean_squared_error', 10),
#  (0.01, 'tanh', 'mean_squared_error', 50),
#  (0.01, 'tanh', 'mean_squared_error', 100),
#  (0.01, 'tanh', 'categorical_crossentropy', 10),
#  (0.01, 'tanh', 'categorical_crossentropy', 50),
#  (0.01, 'tanh', 'categorical_crossentropy', 100),
#  (0.001, 'sigmoid', 'mean_squared_error', 10),
#  (0.001, 'sigmoid', 'mean_squared_error', 50),
#  (0.001, 'sigmoid', 'mean_squared_error', 100),
#  (0.001, 'sigmoid', 'categorical_crossentropy', 10),
#  (0.001, 'sigmoid', 'categorical_crossentropy', 50),
#  (0.001, 'sigmoid', 'categorical_crossentropy', 100),
#  (0.001, 'tanh', 'mean_squared_error', 10),
#  (0.001, 'tanh', 'mean_squared_error', 50),
#  (0.001, 'tanh', 'mean_squared_error', 100),
#  (0.001, 'tanh', 'categorical_crossentropy', 10),
#  (0.001, 'tanh', 'categorical_crossentropy', 50),
#  (0.001, 'tanh', 'categorical_crossentropy', 100)]

# %%
# experiment models
selectedModel = None
selectedModelLoss = None
for experiment, parameters in enumerate(experiments):
  learningRate, activation, loss, epochs = parameters

  # display info
  print(f"Experiment {experiment+1}")
  print(f"Learning Rate: {learningRate}, Activation: {activation}, Loss: {loss}, Epochs: {epochs}")
  print()
  
  # build model
  opt = SGD(learning_rate=learningRate, momentum=0)
  model = keras.Sequential()
  model.add(layers.Conv2D(filters=6, kernel_size=(5, 5), strides=(1,1), activation=activation, input_shape=(32,32,3)))
  model.add(layers.AveragePooling2D(pool_size=(3,3), strides=(2,2)))
  model.add(layers.Conv2D(filters=16, kernel_size=(5, 5), strides=(1,1), activation=activation))
  model.add(layers.AveragePooling2D(pool_size=(3,3), strides=(2,2)))
  model.add(layers.Flatten())
  model.add(layers.Dense(units=120, activation=activation))
  model.add(layers.Dense(units=84, activation=activation))
  model.add(layers.Dense(units=10, activation = 'softmax'))
  model.compile(optimizer=opt, loss=loss, metrics=['accuracy'])
  history = model.fit(x=trainX, y=trainY, epochs=epochs, batch_size=200, validation_data=(testX, testY), verbose=0);
  lossValue = history.history["loss"][-1]

  if(selectedModel == None or selectedModelLoss > lossValue): 
    selectedModel = model
    selectedModelLoss = lossValue
  
  # plot accuracy
  pd.DataFrame(history.history).plot(figsize=(8,5))
  pyplot.legend(["Train Loss", "Train Accuracy", "Test Loss", "Test Accuracy"])
  pyplot.show()
# Out:
# Experiment 1
# Learning Rate: 0.1, Activation: sigmoid, Loss: mean_squared_error, Epochs: 10
# Experiment 2
# Learning Rate: 0.1, Activation: sigmoid, Loss: mean_squared_error, Epochs: 50
# Experiment 3
# Learning Rate: 0.1, Activation: sigmoid, Loss: mean_squared_error, Epochs: 100
# Experiment 4
# Learning Rate: 0.1, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 10
# Experiment 5
# Learning Rate: 0.1, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 50
# Experiment 6
# Learning Rate: 0.1, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 100
# Experiment 7
# Learning Rate: 0.1, Activation: tanh, Loss: mean_squared_error, Epochs: 10
# Experiment 8
# Learning Rate: 0.1, Activation: tanh, Loss: mean_squared_error, Epochs: 50
# Experiment 9
# Learning Rate: 0.1, Activation: tanh, Loss: mean_squared_error, Epochs: 100
# Experiment 10
# Learning Rate: 0.1, Activation: tanh, Loss: categorical_crossentropy, Epochs: 10
# Experiment 11
# Learning Rate: 0.1, Activation: tanh, Loss: categorical_crossentropy, Epochs: 50
# Experiment 12
# Learning Rate: 0.1, Activation: tanh, Loss: categorical_crossentropy, Epochs: 100
# Experiment 13
# Learning Rate: 0.01, Activation: sigmoid, Loss: mean_squared_error, Epochs: 10
# Experiment 14
# Learning Rate: 0.01, Activation: sigmoid, Loss: mean_squared_error, Epochs: 50
# Experiment 15
# Learning Rate: 0.01, Activation: sigmoid, Loss: mean_squared_error, Epochs: 100
# Experiment 16
# Learning Rate: 0.01, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 10
# Experiment 17
# Learning Rate: 0.01, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 50
# Experiment 18
# Learning Rate: 0.01, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 100
# Experiment 19
# Learning Rate: 0.01, Activation: tanh, Loss: mean_squared_error, Epochs: 10
# Experiment 20
# Learning Rate: 0.01, Activation: tanh, Loss: mean_squared_error, Epochs: 50
# Experiment 21
# Learning Rate: 0.01, Activation: tanh, Loss: mean_squared_error, Epochs: 100
# Experiment 22
# Learning Rate: 0.01, Activation: tanh, Loss: categorical_crossentropy, Epochs: 10
# Experiment 23
# Learning Rate: 0.01, Activation: tanh, Loss: categorical_crossentropy, Epochs: 50
# Experiment 24
# Learning Rate: 0.01, Activation: tanh, Loss: categorical_crossentropy, Epochs: 100
# Experiment 25
# Learning Rate: 0.001, Activation: sigmoid, Loss: mean_squared_error, Epochs: 10
# Experiment 26
# Learning Rate: 0.001, Activation: sigmoid, Loss: mean_squared_error, Epochs: 50
# Experiment 27
# Learning Rate: 0.001, Activation: sigmoid, Loss: mean_squared_error, Epochs: 100
# Experiment 28
# Learning Rate: 0.001, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 10
# Experiment 29
# Learning Rate: 0.001, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 50
# Experiment 30
# Learning Rate: 0.001, Activation: sigmoid, Loss: categorical_crossentropy, Epochs: 100
# Experiment 31
# Learning Rate: 0.001, Activation: tanh, Loss: mean_squared_error, Epochs: 10
# Experiment 32
# Learning Rate: 0.001, Activation: tanh, Loss: mean_squared_error, Epochs: 50
# Experiment 33
# Learning Rate: 0.001, Activation: tanh, Loss: mean_squared_error, Epochs: 100
# Experiment 34
# Learning Rate: 0.001, Activation: tanh, Loss: categorical_crossentropy, Epochs: 10
# Experiment 35
# Learning Rate: 0.001, Activation: tanh, Loss: categorical_crossentropy, Epochs: 50
# Experiment 36
# Learning Rate: 0.001, Activation: tanh, Loss: categorical_crossentropy, Epochs: 100

# %%
selectedModel.summary()
